# %% [markdown]
# # **Setup**

# %%
import json
import pandas as pd

# %% [markdown]
# # **Sample Tweet Data**

# %%
# Read JSON File
tweet_json = open('Input Data/tweet-example.json', 'r').read()

# Convert from JSON to Python object
tweet = json.loads(tweet_json)

# Print tweet text
print(tweet['text'])

# Print tweet id
print(tweet['id'])
# Out:
# Writing out the script of my @DataCamp class and I can't help but mentally read it back to myself in @hugobowne's voice.
# 986973961295720449

# %% [markdown]
# ## **Access User Data**

# %%
# Print user handle
print(tweet['user']['screen_name'])

# Print user follower count
print(tweet['user']['followers_count'])

# Print user location
print(tweet['user']['location'])

# Print user description
print(tweet['user']['description'])
# Out:
# alexhanna
# 4267
# Toronto, ON
# Assistant professor @UofT. Protest, media, computation. Trans. Roller derby athlete @TOROLLERDERBY (Kate Silver #538). She/her.

# %% [markdown]
# ## **Access Retweet Data**

# %%
# Read JSON File
retweets = open('Input Data/retweeted-example.json', 'r').read()

# Convert from JSON to Python object
rt = json.loads(retweets)

# Print the text of the tweet
print(rt['text'])

# Print the text of tweet which has been retweeted
print(rt['retweeted_status']['text'])

# Print the user handle of the tweet
print(rt['user']['screen_name'])

# Print the user handle of the tweet which has been retweeted
print(rt['retweeted_status']['user']['screen_name'])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[9], line 5
#       2 retweets = open('Input Data/retweeted-example.json', 'r').read()
#       4 # Convert from JSON to Python object
# ----> 5 rt = json.loads(retweets)
#       7 # Print the text of the tweet
#       8 print(rt['text'])
#
# File c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# ...

# %% [markdown]
# # **Data Processing**

# %% [markdown]
# ## **Flatten Tweets**

# %%
def flatten_tweets(tweets_json):
    """ Flattens out tweet dictionaries so relevant JSON
        is in a top-level dictionary."""
    tweets_list = []
    
    # Iterate through each tweet
    for tweet in tweets_json:
        tweet_obj = json.loads(tweet)
    
        # Store the user screen name in 'user-screen_name'
        tweet_obj['user-screen_name'] = tweet_obj['user']['screen_name']
    
        # Check if this is a 140+ character tweet
        if 'extended_tweet' in tweet_obj:
            # Store the extended tweet text in 'extended_tweet-full_text'
            tweet_obj['extended_tweet-full_text'] = tweet_obj['extended_tweet']['full_text']
    
        if 'retweeted_status' in tweet_obj:
            # Store the retweet user screen name in 'retweeted_status-user-screen_name'
            tweet_obj['retweeted_status-user-screen_name'] = tweet_obj['retweeted_status']['user']['screen_name']

            # Store the retweet text in 'retweeted_status-text'
            tweet_obj['retweeted_status-text'] = tweet_obj['retweeted_status']['text']
            
        tweets_list.append(tweet_obj)
    return tweets_list

# %%
# Read JSON File
data_science_json = open('Input Data/data_science_tweets.json','r',encoding=None).read()
data_science_json = json.loads(data_science_json)

# Flatten the tweets and store in `tweets`
ds_tweets = pd.DataFrame(flatten_tweets(data_science_json))

# Print out the first 5 tweets from this dataset
# print(ds_tweets['text'].values[0:5])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[46], line 3
#       1 # Read JSON File
#       2 data_science_json = open('Input Data/data_science_tweets.json','r',encoding=None).read()
# ----> 3 data_science_json = json.loads(data_science_json)
#       5 # Flatten the tweets and store in `tweets`
#       6 ds_tweets = pd.DataFrame(flatten_tweets(data_science_json))
#
# File c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
# ...
