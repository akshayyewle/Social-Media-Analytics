# %% [markdown]
# # **Setup**

# %%
import pandas as pd 
import numpy as np 
from IPython.display import clear_output
import tweepy
import os

# %%
# Twitter API Keys
API_Key = os.getenv('TwitterAPI_Key')
API_Secret_Key = os.getenv('TwitterAPI_Secret_Key')
Bearer_Token = 'KEY'
Access_Token = os.getenv('TwitterAPI_Access_Token')
Access_Token_Secret = os.getenv('TwitterAPI_Access_Token_Secret')

# %%
# Authenticate to Twitter
auth = tweepy.OAuthHandler(API_Key, API_Secret_Key)
auth.set_access_token(Access_Token,Access_Token_Secret)

# %% [markdown]
# # **Data Import**

# %%
# OAuth2.0 Version 
import tweepy

#Put your Bearer Token in the parenthesis below
API = tweepy.API(auth)

# %%
# Set Query Parameters
# -is:retweet means I don't want retweets
# lang:en is asking for the tweets to be in english
Query_Settings = '#IsraelAttack OR #Hamas'
No_Of_Tweets = 5
Date_Since = '2023-10-10'

# %%
Query_Settings
# Out:
# '#IsraelAttack OR #Hamas'

# %%
tweets = API.search_tweets(q = Query_Settings)
# Out:
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:301: SyntaxWarning: invalid escape sequence '\['
#   """home_timeline(*, count, since_id, max_id, trim_user, \
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:341: SyntaxWarning: invalid escape sequence '\['
#   """mentions_timeline(*, count, since_id, max_id, trim_user, \
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:376: SyntaxWarning: invalid escape sequence '\['
#   """user_timeline(*, user_id, screen_name, since_id, count, max_id, \
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:426: SyntaxWarning: invalid escape sequence '\['
#   """get_favorites(*, user_id, screen_name, count, since_id, max_id, \
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:467: SyntaxWarning: invalid escape sequence '\['
#   """lookup_statuses(id, *, include_entities, trim_user, map, \
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:599: SyntaxWarning: invalid escape sequence '\['
#   """get_retweeter_ids(id, *, count, cursor, stringify_ids)
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:634: SyntaxWarning: invalid escape sequence '\['
#   """get_retweets(id, *, count, trim_user)
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:667: SyntaxWarning: invalid escape sequence '\['
#   """get_retweets_of_me(*, count, since_id, max_id, trim_user, \
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:1055: SyntaxWarning: invalid escape sequence '\ '
#   """search_tweets(q, *, geocode, lang, locale, result_type, count, \
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:1157: SyntaxWarning: invalid escape sequence '\['
#   """get_lists(*, user_id, screen_name, reverse)
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:1202: SyntaxWarning: invalid escape sequence '\['
#   """get_list_members(*, list_id, slug, owner_screen_name, owner_id, \
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:1299: SyntaxWarning: invalid escape sequence '\['
#   """get_list_memberships(*, user_id, screen_name, count, cursor, \
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:1342: SyntaxWarning: invalid escape sequence '\['
#   """get_list_ownerships(*, user_id, screen_name, count, cursor)
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:1409: SyntaxWarning: invalid escape sequence '\['
#   """list_timeline( \
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:1460: SyntaxWarning: invalid escape sequence '\['
#   """get_list_subscribers( \
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:1559: SyntaxWarning: invalid escape sequence '\['
#   """get_list_subscriptions(*, user_id, screen_name, count, cursor)
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:1927: SyntaxWarning: invalid escape sequence '\['
#   """get_follower_ids(*, user_id, screen_name, cursor, stringify_ids, \
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:1966: SyntaxWarning: invalid escape sequence '\['
#   """get_followers(*, user_id, screen_name, cursor, count, skip_status, \
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:2008: SyntaxWarning: invalid escape sequence '\['
#   """get_friend_ids(*, user_id, screen_name, cursor, stringify_ids, \
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:2047: SyntaxWarning: invalid escape sequence '\['
#   """get_friends(*, user_id, screen_name, cursor, count, skip_status, \
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:2089: SyntaxWarning: invalid escape sequence '\['
#   """incoming_friendships(*, cursor, stringify_ids)
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:2120: SyntaxWarning: invalid escape sequence '\['
#   """lookup_friendships(*, screen_name, user_id)
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:2149: SyntaxWarning: invalid escape sequence '\['
#   """no_retweets_friendships(*, stringify_ids)
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:2176: SyntaxWarning: invalid escape sequence '\['
#   """outgoing_friendships(*, cursor, stringify_ids)
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:2243: SyntaxWarning: invalid escape sequence '\['
#   """lookup_users(*, screen_name, user_id, include_entities, tweet_mode)
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:2290: SyntaxWarning: invalid escape sequence '\['
#   """search_users(q, *, page, count, include_entities)
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:2500: SyntaxWarning: invalid escape sequence '\['
#   """get_saved_searches()
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:2814: SyntaxWarning: invalid escape sequence '\['
#   """get_blocked_ids(*, stringify_ids, cursor)
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:2846: SyntaxWarning: invalid escape sequence '\['
#   """get_blocks(*, include_entities, skip_status, cursor)
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:2880: SyntaxWarning: invalid escape sequence '\['
#   """get_muted_ids(*, stringify_ids, cursor)
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:2911: SyntaxWarning: invalid escape sequence '\['
#   """get_mutes(*, cursor, include_entities, skip_status)
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:3126: SyntaxWarning: invalid escape sequence '\['
#   """get_direct_messages(*, count, cursor)
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:3788: SyntaxWarning: invalid escape sequence '\['
#   """reverse_geocode(lat, long, *, accuracy, granularity, max_results)
# c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:3829: SyntaxWarning: invalid escape sequence '\['
#   """search_geo(*, lat, long, query, ip, granularity, max_results)
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 tweets = API.search_tweets(q = Query_Settings)
#
# File c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:33, in pagination.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      31 @functools.wraps(method)
#      32 def wrapper(*args, **kwargs):
# ---> 33     return method(*args, **kwargs)
#
# File c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:46, in payload.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      44 kwargs['payload_list'] = payload_list
#      45 kwargs['payload_type'] = payload_type
# ---> 46 return method(*args, **kwargs)
#
# File c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:1146, in API.search_tweets(self, q, **kwargs)
#    1052 @pagination(mode='id')
#    1053 @payload('search_results')
#    1054 def search_tweets(self, q, **kwargs):
#    1055     """search_tweets(q, *, geocode, lang, locale, result_type, count, \
#    1056                      until, since_id, max_id, include_entities)
#    1057
#    (...)
#    1144     .. _Twitter's documentation on the standard search API: https://developer.twitter.com/en/docs/twitter-api/v1/tweets/search/overview
#    1145     """
# -> 1146     return self.request(
#    1147         'GET', 'search/tweets', endpoint_parameters=(
#    1148             'q', 'geocode', 'lang', 'locale', 'result_type', 'count',
#    1149             'until', 'since_id', 'max_id', 'include_entities'
#    1150         ), q=q, **kwargs
#    1151     )
#
# File c:\Users\aksha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:271, in API.request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     269     raise Unauthorized(resp)
#     270 if resp.status_code == 403:
# --> 271     raise Forbidden(resp)
#     272 if resp.status_code == 404:
#     273     raise NotFound(resp)
#
# Forbidden: 403 Forbidden
# 453 - You currently have access to a subset of Twitter API v2 endpoints and limited v1.1 endpoints (e.g. media post, oauth) only. If you need access to this endpoint, you may need a different access level. You can learn more here: https://developer.twitter.com/en/portal/product
